# %%
import pandas as pd
import os
from sqlalchemy import create_engine 
import logging 
import time

logging.basicConfig(
    filename='logs/ingestion.log',
    level = logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filemode='a'
    
)

server = "localhost\\SQLEXPRESS01"
database = "inventory"

engine = create_engine(
    f"mssql+pyodbc://{server}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

def ingest_db(df, table_name, engine):
    '''this function will ingest the dataframe into database tables'''
    df.to_sql(table_name, con=engine, if_exists='replace', index=False) 


def load_raw_data():
    '''this function will load the CSVs as dataframe and ingest into DB  '''
    start = time.time()
    for file in os.listdir('data'):
        if '.csv' in file:
            df = pd.read_csv('data/'+file)
            logging.info(f'Ingesting {file} in DB')
            ingest_db(df, file[:-4], engine)
    end = time.time()
    total_time = (end - start)/60
    logging.info('---------------Ingestion Completed---------------')
    logging.info(f'\nTotal Time Taken {total_time}')

if __name__ == '__main__':
    load_raw_data()
# Out:
# C:\Users\KUBAR TECH STORE\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\sql.py:1649: SAWarning: Unrecognized server version info '17.0.1050.2'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())
